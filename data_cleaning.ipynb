# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Mark\Downloads\Data\newhealthcaredatset.csv")

print(df.shape)
df.head()
# Out:
# (30719, 15)
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0    18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1    33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2    27955.096079          205      Emergency     2022-10-07      Aspirin
# 3    37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4    14238.317814          458         Urgent     2022-10-09   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30719 entries, 0 to 30718
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                30719 non-null  str
#  1   Age                 30719 non-null  int64
#  2   Gender              30719 non-null  str
#  3   Blood Type          30719 non-null  str
#  4   Medical Condition   30719 non-null  str
#  5   Date of Admission   30719 non-null  str
#  6   Doctor              30719 non-null  str
#  7   Hospital            30719 non-null  str
#  8   Insurance Provider  30719 non-null  str
#  9   Billing Amount      30719 non-null  float64
#  10  Room Number         30719 non-null  int64
#  11  Admission Type      30719 non-null  str
#  12  Discharge Date      30719 non-null  str
#  13  Medication          30719 non-null  str
#  14  Test Results        30719 non-null  str
# dtypes: float64(1), int64(2), str(12)
# memory usage: 3.5 MB
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (30719, 15)

# %%
for col in df.columns:
    if df[col].dtype in ['float64', 'int64']:
        df[col] = df[col].fillna(df[col].median())
    else:
        df[col] = df[col].fillna(df[col].mode()[0])

# %%
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.strip().str.title()
# Out:
# C:\Users\Mark\AppData\Local\Temp\ipykernel_12000\1061859639.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df.select_dtypes(include='object').columns:

# %%
for col in df.columns:
    if "date" in col.lower():
        df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
if 'Age' in df.columns:
    df = df[(df['Age'] >= 0) & (df['Age'] <= 100)]

# %%
df.to_csv("cleaned_healthcare_dataset.csv", index=False)
